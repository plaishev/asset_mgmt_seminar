# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
japan = pd.read_excel("./data/Price History_EWJ_Japan_Equity.xlsx")
t_bills_7_10 = pd.read_excel("./data/Price History_7-10_US_TBills.xlsx")
t_bills_20 = pd.read_excel("./data/Price History_20+_US_TBills.xlsx")
apac_x_japan = pd.read_excel("./data/Price History_EPP_APACxJapan_Equity.xlsx")
europe = pd.read_excel("./data/Price History_IEV_Europe_Equity.xlsx")
latam = pd.read_excel("./data/Price History_ILF_LatAm_Equity.xlsx")
us = pd.read_excel("./data/Price History_IVV_US_Equity.xlsx")
gold = pd.read_excel("./data/Price History_IAU_Gold_Trust.xlsx")

# %%
us.head()
# Out:
#   Exchange Date   Close   Net      %Chg    Open       Low    High   Volume  \
# 0    2024-12-13  607.24 -0.11 -0.000181  609.44  605.8278  610.15  9729091
# 1    2024-12-12  607.35 -3.24 -0.005306  609.63  607.3500  610.17  5830787
# 2    2024-12-11  610.59  4.67  0.007707  608.80  608.5080  611.48  4892064
# 3    2024-12-10  605.92 -1.76 -0.002896  608.39  605.1600  608.72  4489053
# 4    2024-12-09  607.68 -3.15 -0.005157  610.75  607.0900  610.85  2973765
#
#    Turnover - USD
# 0    5.909573e+09
# 1    3.545192e+09
# 2    2.986816e+09
# 3    2.723671e+09
# 4    1.809882e+09

# %%
# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(gold['Exchange Date'], gold['Close'], marker='', label='Gold')
plt.plot(us['Exchange Date'], us['Close'], marker='', label='USA')
plt.plot(europe['Exchange Date'], europe['Close'], marker='', label='Europe')
plt.plot(apac_x_japan['Exchange Date'], apac_x_japan['Close'], marker='', label='APAC ex. Japan')
plt.plot(japan['Exchange Date'], japan['Close'], marker='', label='Japan')
plt.plot(latam['Exchange Date'], latam['Close'], marker='', label='LatAm')
plt.plot(us['Exchange Date'], us['Close'], marker='', label='USA')



# Customize the plot
plt.title("Close Price by Exchange Date", fontsize=16)
plt.xlabel("Exchange Date", fontsize=12)
plt.ylabel("Close Price (USD)", fontsize=12)
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)  # Rotate date labels for better readability

# Show the plot
plt.tight_layout()  # Adjust layout for better appearance
plt.show()
